# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data_order = pd.read_csv('C:/Users/sogut/Desktop/Test/citibike2016.csv')
print(data_order)
# Out:
#                  start_time            stop_time  start_station_id  \
# 0       2016-01-01 00:02:52  2016-01-01 00:08:54              3186
# 1       2016-01-01 00:18:22  2016-01-01 00:21:42              3186
# 2       2016-01-01 00:18:25  2016-01-01 00:21:47              3186
# 3       2016-01-01 00:23:13  2016-01-01 00:27:21              3209
# 4       2016-01-01 01:03:20  2016-01-01 01:18:24              3195
# ...                     ...                  ...               ...
# 247579  2016-12-31 23:10:16  2016-12-31 23:19:33              3214
# 247580  2016-12-31 23:29:39  2017-01-01 00:15:29              3183
# 247581  2016-12-31 23:44:37  2016-12-31 23:47:31              3186
# 247582  2016-12-31 23:44:50  2017-01-01 00:25:14              3214
# 247583  2016-12-31 23:44:50  2017-01-01 00:25:10              3214
#
#         end_station_id  bike_id   user_type  birth_year  gender
# 0                 3209    24647  Subscriber      1964.0       2
# ...

# %%
data_order.columns
# Out:
# Index(['start_time', 'stop_time', 'start_station_id', 'end_station_id',
#        'bike_id', 'user_type', 'birth_year', 'gender'],
#       dtype='object')

# %%
data_order.describe()
# Out:
#        start_station_id  end_station_id        bike_id     birth_year  \
# count     247584.000000   247584.000000  247584.000000  228585.000000
# mean        3207.065206     3203.572553   24935.260481    1979.335276
# std           26.955103       61.579494     748.469712       9.596809
# min         3183.000000      147.000000   14552.000000    1900.000000
# 25%         3186.000000     3186.000000   24491.000000    1974.000000
# 50%         3201.000000     3199.000000   24609.000000    1981.000000
# 75%         3211.000000     3211.000000   24719.000000    1986.000000
# max         3426.000000     3426.000000   27274.000000    2000.000000
#
#               gender
# count  247584.000000
# mean        1.123534
# std         0.518687
# min         0.000000
# 25%         1.000000
# 50%         1.000000
# 75%         1.000000
# max         2.000000

# %%
data_order.corr()
# Out:
# C:\Users\sogut\AppData\Local\Temp\ipykernel_18680\17949130.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data_order.corr()
#                   start_station_id  end_station_id   bike_id  birth_year  \
# start_station_id          1.000000       -0.026318  0.122679   -0.000956
# end_station_id           -0.026318        1.000000  0.049260    0.002383
# bike_id                   0.122679        0.049260  1.000000    0.014303
# birth_year               -0.000956        0.002383  0.014303    1.000000
# gender                    0.034118        0.017464  0.004252    0.076235
#
#                     gender
# start_station_id  0.034118
# end_station_id    0.017464
# bike_id           0.004252
# birth_year        0.076235
# gender            1.000000

# %%
import seaborn as sns
plt.style.use('seaborn-whitegrid')
plt.figure(figsize=(10,10))
dataplot = sns.heatmap(data_order.corr(),  annot=True, cmap='BuPu')
# Out:
# C:\Users\sogut\AppData\Local\Temp\ipykernel_18680\3675884343.py:2: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-whitegrid')
# C:\Users\sogut\AppData\Local\Temp\ipykernel_18680\3675884343.py:4: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   dataplot = sns.heatmap(data_order.corr(),  annot=True, cmap='BuPu')

# %%
data_order
# Out:
#                  start_time            stop_time  start_station_id  \
# 0       2016-01-01 00:02:52  2016-01-01 00:08:54              3186
# 1       2016-01-01 00:18:22  2016-01-01 00:21:42              3186
# 2       2016-01-01 00:18:25  2016-01-01 00:21:47              3186
# 3       2016-01-01 00:23:13  2016-01-01 00:27:21              3209
# 4       2016-01-01 01:03:20  2016-01-01 01:18:24              3195
# ...                     ...                  ...               ...
# 247579  2016-12-31 23:10:16  2016-12-31 23:19:33              3214
# 247580  2016-12-31 23:29:39  2017-01-01 00:15:29              3183
# 247581  2016-12-31 23:44:37  2016-12-31 23:47:31              3186
# 247582  2016-12-31 23:44:50  2017-01-01 00:25:14              3214
# 247583  2016-12-31 23:44:50  2017-01-01 00:25:10              3214
#
#         end_station_id  bike_id   user_type  birth_year  gender
# 0                 3209    24647  Subscriber      1964.0       2
# ...

# %%
data_order = data_order.groupby(['start_station_id','end_station_id']).size().reset_index(name='counts')
data_order = data_order.sort_values(by='counts', ascending=False)
data_order
# Out:
#       start_station_id  end_station_id  counts
# 850               3203            3186    5742
# 1026              3209            3186    5553
# 485               3194            3195    4728
# 183               3186            3203    4135
# 1211              3213            3186    3954
# ...                ...             ...     ...
# 1259              3214             428       1
# 1258              3214             390       1
# 1257              3214             359       1
# 1255              3214             328       1
# 1971              3426            3188       1
#
# [1972 rows x 3 columns]

# %%
import plotly.express as px
import matplotlib.pyplot as plt

plt.figure(figsize=(15,12))
fig = px.bar(data_order, x='start_station_id', y='end_station_id', color='counts', barmode='group', height=1000)
fig.show()

# %%
dt_order = pd.read_csv('C:/Users/sogut/Desktop/Test/citibike2016.csv')
print(dt_order)
dt_order.columns
# Out:
#                  start_time            stop_time  start_station_id  \
# 0       2016-01-01 00:02:52  2016-01-01 00:08:54              3186
# 1       2016-01-01 00:18:22  2016-01-01 00:21:42              3186
# 2       2016-01-01 00:18:25  2016-01-01 00:21:47              3186
# 3       2016-01-01 00:23:13  2016-01-01 00:27:21              3209
# 4       2016-01-01 01:03:20  2016-01-01 01:18:24              3195
# ...                     ...                  ...               ...
# 247579  2016-12-31 23:10:16  2016-12-31 23:19:33              3214
# 247580  2016-12-31 23:29:39  2017-01-01 00:15:29              3183
# 247581  2016-12-31 23:44:37  2016-12-31 23:47:31              3186
# 247582  2016-12-31 23:44:50  2017-01-01 00:25:14              3214
# 247583  2016-12-31 23:44:50  2017-01-01 00:25:10              3214
#
#         end_station_id  bike_id   user_type  birth_year  gender
# 0                 3209    24647  Subscriber      1964.0       2
# ...

# %%
import plotly.express as px
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

df1 = pd.read_csv('C:/Users/sogut/Desktop/Test/citibike2016.csv')
df1 = df1.head(1000)


df1 = df1[['start_time']]
df1 = df1.rename(columns={'start_time':'start'})
df2 = df1.groupby(['start']).size().reset_index(name='counts')
fig3 = px.line(df2, x='start', y='counts', title='Start Time')
fig3.show()

# %%
import plotly.express as px
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

df1 = pd.read_csv('C:/Users/sogut/Desktop/Test/citibike2016.csv')
print(df1.columns)
#create customer and subscriber dataframes

p = df1.groupby(['user_type']).size().reset_index(name='counts')
fig = px.pie(p, values='counts', names='user_type', title='User Type')
fig.show()
# Out:
# Index(['start_time', 'stop_time', 'start_station_id', 'end_station_id',
#        'bike_id', 'user_type', 'birth_year', 'gender'],
#       dtype='object')

# %%
# birth year 
import plotly.express as px
import matplotlib.pyplot as plt
import seaborn as sns

df1 = pd.read_csv('C:/Users/sogut/Desktop/Test/citibike2016.csv')
birth_year = df1['birth_year'].tolist()
plt.style.use('Solarize_Light2')
plt.figure(figsize=(10,10))
plt.hist(birth_year, bins=100)
plt.xlabel('Birth Year')
plt.ylabel('Counts')
plt.show()

# %%
# birth year 
import plotly.express as px
import matplotlib.pyplot as plt
import seaborn as sns

df1 = pd.read_csv('C:/Users/sogut/Desktop/Test/citibike2016.csv')
plt.style.use('Solarize_Light2')
df1 = df1.groupby(['birth_year']).size().reset_index(name='counts')
plt.scatter(df1['birth_year'], df1['counts'],color='purple',marker='o',s=20,label='Birth Year')
plt.xlabel('Birth Year')
plt.ylabel('Counts')
plt.show()

# %%
import plotly.express as px
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

df1 = pd.read_csv('C:/Users/sogut/Desktop/Test/citibike2016.csv')
print(df1.columns)
#create gender
df1 = df1.groupby(['gender']).size().reset_index(name='counts')

print(df1)

fig = px.pie(df1, values = 'counts', names = 'gender', title ='Gender')
fig.show()
# Out:
# Index(['start_time', 'stop_time', 'start_station_id', 'end_station_id',
#        'bike_id', 'user_type', 'birth_year', 'gender'],
#       dtype='object')
#    gender  counts
# 0       0   19901
# 1       1  177197
# 2       2   50486
